# %%
path = 'trafficSignModel.pt'

# %%
from ultralytics import YOLO

model = YOLO(path)
# Export with opset=12 and dynamic shape
model.export(format="onnx", opset=12, dynamic=True)

# %%
import torch
from ultralytics.nn.tasks import DetectionModel
import json
with torch.serialization.safe_globals([DetectionModel]):
    ckpt = torch.load(path, map_location="cpu", weights_only=False)

model = ckpt['model']  # Đây là DetectionModel
names = model.names    # trực tiếp từ object
print(names)
with open("classes_v1.json", "w", encoding="utf-8") as f:
    json.dump(names, f, indent=2, ensure_ascii=False)

print("Saved classes.json successfully!")
# Out:
# {0: 'bat-dau-duong-uu-tien', 1: 'cam-bop-coi', 2: 'cam-di-nguoc-chieu', 3: 'cam-do-xe', 4: 'cam-do-xe-ngay-chan', 5: 'cam-do-xe-ngay-le', 6: 'cam-dung-va-do-xe', 7: 'cam-nguoi-di-bo', 8: 'cam-o-to', 9: 'cam-quay-dau-xe', 10: 'cam-re-phai', 11: 'cam-re-trai', 12: 'cam-xe-2-banh-3-banh', 13: 'cam-xe-3-banh-xe-tho-so-4-banh', 14: 'cam-xe-somi-romooc', 15: 'cam-xe-tai', 16: 'chieu-cao-tinh-khong-thuc-te', 17: 'cho-ngoat-nguy-hiem-ben-phai', 18: 'cho-ngoat-nguy-hiem-ben-trai', 19: 'cong-truong-dang-thi-cong', 20: 'di-cham', 21: 'duong-cam', 22: 'duong-co-go-giam-toc', 23: 'duong-cut', 24: 'duong-mot-chieu', 25: 'duong-nguoi-di-bo-cat-ngang', 26: 'giao-nhau-voi-duong-uu-tien', 27: 'han-che-chieu-cao', 28: 'han-che-trong-luong-xe', 29: 'het-duong-uu-tien', 30: 'huong-phai-di-vong-chuong-ngai-vat', 31: 'khu-vuc-cho-phia-truoc', 32: 'nhieu-cho-ngoat-nguy-hiem-lien-tiep', 33: 'noi-giao-nhau-chay-theo-vong-xuyen', 34: 'noi-giao-nhau-voi-duong-sat-co-rao-chan', 35: 'toc-do-toi-da-cho-phep', 36: 'tre-em-qua-duong'}
# Saved classes.json successfully!
